# %% [markdown]
# So far we've learnt the most basic but crucial algorithms a data scientist and a machine learning engineer must know. We've learnt the techniques for classification and regression, and we've done some very rudementary data exploration. Hopefully, you've also done the assignments and the mini projects in the courses we recommended you to do. In this assignment, we give you a very easy dataset on which you can perform both classification and regression tasks. The purpose of this assignment is for you to try your hand out at all the techniques you've learnt so far and work on a real dataset to figure out whether what you learnt up until now works.

# %% [markdown]
# ## Link to the Dataset
#
# https://archive.ics.uci.edu/ml/datasets/wine+quality

# %% [markdown]
# For you to submit this assingment, you'll have to give us the accuracy you're getting on your classification, what algorithms/techniques you used for classification and why. Also, you'll give us the minimum loss you got in your regression, what algorithms/techniques you used and why. Just as last assignment, you'll clone the original folder, work completely on this Jupyter notebook and submit all your work. Also, you'll include in a text cell the above things. Happy playing on this dataset!

# %% [markdown]
# ## Some things that must be present in the notebook
# - Read the dataset and display various details of data (correlation,some statistics etc..)
# - Split the data into train test split
# - Show some vizualizations
# - Models for both classification and regression.
# - Show the results clearly and all of them must be on the test set

# %% [markdown]
# This [book](https://github.com/dvrg/educate-resource-for-machine-learning/blob/master/6.%20Machine%20Learning%20Mastery%20With%20Python%20Understand%20Your%20Data%2C%20Create%20Accurate%20Models%20and%20work%20Projects%20End-to-End.pdf) is a great resource for data science/predictive modelling in general and can be used as reference book for this task and future. The book highlights all the necessary steps one must take to understand data and build powerful models in a simple and understandable manner.

# %% [markdown]
# ### Accuracy on your classification task and the reason you used this algorithm/technique ->

# %% [markdown]
# ### Minimum loss on you regression task and the reason you used this algorithm/technique ->

# %% [markdown]
# # I have done classification and regression by taking the red wine  data and white wine data differently first .After getting the result I have combined the two data to do classification and regression on the combined data

# %%
import pandas as pd

# %%
import numpy

# %%
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("winequality-white.csv")

# %%
data1=pd.read_csv("winequality-red.csv")

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data1.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
corr = data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_1796d84a_8f32_11e9_8560_6030d4648f7erow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1796d84a_8f32_11e9_8560_6030d4648f7erow0_col1 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_1796d84a_8f32_11e9_8560_6030d4648f7erow0_col2 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_1796d84a_8f32_11e9_8560_6030d4648f7erow0_col3 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_1796d84a_8f32_11e9_8560_6030d4648f7erow0_col4 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_1796d84a_8f32_11e9_8560_6030d4648f7erow0_col5 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_1796d84a_8f32_11e9_8560_6030d4648f7erow0_col6 {
#             background-color:  #b7cff9;
#             color:  #000000;
# ...

# %%
corr1=data1.corr()
corr1.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_17ac41a8_8f32_11e9_b5b2_6030d4648f7erow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_17ac41a8_8f32_11e9_b5b2_6030d4648f7erow0_col1 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_17ac41a8_8f32_11e9_b5b2_6030d4648f7erow0_col2 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_17ac41a8_8f32_11e9_b5b2_6030d4648f7erow0_col3 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_17ac41a8_8f32_11e9_b5b2_6030d4648f7erow0_col4 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_17ac41a8_8f32_11e9_b5b2_6030d4648f7erow0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_17ac41a8_8f32_11e9_b5b2_6030d4648f7erow0_col6 {
#             background-color:  #516ddb;
#             color:  #000000;
# ...

# %% [markdown]
#                     I am making the features and the value to be predicted that is 'quality'
#                     to get store in diffent variables so that i
#                     can use the sklearn for classification and regression

# %%
data.describe()#white wine
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
data1.describe()#red wine
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
class_white=data.groupby('quality').size()
print(class_white)
# Out:
# quality
# 3      20
# 4     163
# 5    1457
# 6    2198
# 7     880
# 8     175
# 9       5
# dtype: int64

# %%
class_red=data1.groupby('quality').size()
print(class_red)
# Out:
# quality
# 3     10
# 4     53
# 5    681
# 6    638
# 7    199
# 8     18
# dtype: int64

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36           20.70      0.045
# 1               6.3             0.300         0.34            1.60      0.049
# 2               8.1             0.280         0.40            6.90      0.050
# 3               7.2             0.230         0.32            8.50      0.058
# 4               7.2             0.230         0.32            8.50      0.058
# 5               8.1             0.280         0.40            6.90      0.050
# 6               6.2             0.320         0.16            7.00      0.045
# 7               7.0             0.270         0.36           20.70      0.045
# 8               6.3             0.300         0.34            1.60      0.049
# 9               8.1             0.220         0.43            1.50      0.044
# 10              8.1             0.270         0.41            1.45      0.033
# ...

# %%
data.hist()
plt.show()

# %% [markdown]
# after seeing the histogram of residual sugar and analysing the data we can see that that the
# value of residual sugar revolves between 0 to 5 .so i m deleting the rows where the value of the residual sugar is greater than five

# %%
data=data[data['residual sugar']<=20]

# %%
drop=data[data['free sulfur dioxide']>100]
print(drop.shape)
drop1=data[data['free sulfur dioxide']<10]
print(drop1.shape)
# Out:
# (17, 12)
# (167, 12)

# %% [markdown]
# Now to prevent overfitting i m erasing the data where free sulfur dioxide is greater than 100 and smaller than 10

# %%
data=data[data['free sulfur dioxide']<=100]

# %%
data=data[data['free sulfur dioxide']>=10]

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(data,figsize=(24,24),diagonal='hist')
plt.show()

# %%
arr=data.values

# %%
X=arr[:,0:11]
Y=arr[:,11]

# %% [markdown]
# I am using the univariate method for feature selection

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
test=SelectKBest(score_func=chi2,k=6)
fit=test.fit(X,Y)

# %%
from numpy import set_printoptions

# %%
set_printoptions(precision=3)
print(fit.scores_)
features=fit.transform(X)
print(features)
X=features
# Out:
# [8.383e+00 1.105e+01 5.121e-01 4.550e+02 2.662e+00 3.439e+02 3.423e+03
#  5.267e-03 3.922e-01 4.729e-01 1.564e+02]
# [[  6.3    0.3    1.6   14.   132.     9.5 ]
#  [  8.1    0.28   6.9   30.    97.    10.1 ]
#  [  7.2    0.23   8.5   47.   186.     9.9 ]
#  ...
#  [  6.5    0.24   1.2   30.   111.     9.4 ]
#  [  5.5    0.29   1.1   20.   110.    12.8 ]
#  [  6.     0.21   0.8   22.    98.    11.8 ]]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=20)

from sklearn.ensemble import RandomForestClassifier as rfc
clf=rfc(max_features=6,random_state=0)
clf.fit(X_train,Y_train)
ans=clf.predict(X_test)
from sklearn.metrics import accuracy_score as acs
k=acs(ans,Y_test)
print(k)
# Out:
# /Users/amankumar/Desktop/anaconda/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.651618398637138

# %% [markdown]
# # the accuracy score is 0.6609 with the classifier for white wine data
# HERE I HAVE USED RANDOM FOREST CLASSIFIER.
# EXPLANATION BELOW

# %% [markdown]
# # the classifier for the red wine data

# %%
scatter_matrix(data1,figsize=(24,24),diagonal='hist')
plt.show()

# %%
data1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# ...

# %%
drop=data1[data1['total sulfur dioxide']>140]
print(drop.shape)
drop1=data1[data1['total sulfur dioxide']<10]
print(drop1.shape)
# Out:
# (27, 12)
# (35, 12)

# %%
data1=data1[data1['total sulfur dioxide']<=140]
data1=data1[data1['total sulfur dioxide']>=10]

arr1=data1.values
X1=arr1[:,0:11]
Y1=arr1[:,11]

# %%
#test1=SelectKBest(score_func=chi2,k=6)
#fit1=test1.fit(X1,Y1)

# %%
#set_printoptions(precision=3)
#print(fit1.scores_)
#features=fit1.transform(X1)
#print(features)
#X1=features

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X1,Y1,test_size=0.2,random_state=20)

from sklearn.ensemble import RandomForestClassifier as rfc
clf=rfc(max_features=5,random_state=0)
clf.fit(X_train,Y_train)
ans=clf.predict(X_test)
from sklearn.metrics import accuracy_score as acs
k=acs(ans,Y_test)
print(k)
# Out:
# 0.6785714285714286
# /Users/amankumar/Desktop/anaconda/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %% [markdown]
# # ACCURACY =67% WITH RED WINE DATA AND USING RANDOM FOREST

# %% [markdown]
# I am using the random forest classifier after checking all the other classifiers such as svm ,naivebayes,and decision
# trees.With all the three I was getting no more than 60%accuracy but here i am getting 67%accuracy .
# This algorithm takes care of all the features while making the prediction by forming different random trees for the features.Then prediction are made using each of the  trees  and then real prediction is done by taking average of all.I think this is the best algo if we are dealing in multiple features

# %% [markdown]
# # Now I am starting with the regression task

# %% [markdown]
# # The red wine regression

# %%
X1_train,X1_test,Y1_train,Y1_test=train_test_split(X1,Y1,test_size=0.25,random_state=20)

# %%
from sklearn.ensemble import RandomForestRegressor as dtr

# %%
model=dtr()

# %%
model.fit(X1_train,Y1_train)
# Out:
# /Users/amankumar/Desktop/anaconda/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
ans1=model.predict(X1_test)
from sklearn.metrics import mean_squared_error,accuracy_score
k=mean_squared_error(ans1,Y1_test)
#k1=accuracy_score(ans1,Y_test)
print(k)
#print(k1)
# Out:
# 0.43685714285714283

# %% [markdown]
# # Error 0.43

# %% [markdown]
# # regression with white wine model

# %%
X2_train,X2_test,Y2_train,Y2_test=train_test_split(X,Y,test_size=0.2,random_state=20)

# %%
model1=dtr()

# %%
model1.fit(X2_train,Y2_train)
# Out:
# /Users/amankumar/Desktop/anaconda/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
#print(X_test.shape)
ans2=model1.predict(X2_test)

from sklearn.metrics import mean_squared_error
k1=mean_squared_error(ans2,Y2_test)
#k1=accuracy_score(ans1,Y_test)
print(k1)
# Out:
# 0.4107127659574469

# %% [markdown]
# # Error 0.41

# %% [markdown]
# # Now  i am combining the predicted data and the testing data of both the wines

# %%
Y1_test=pd.DataFrame(Y1_test)
Y2_test=pd.DataFrame(Y2_test)
ans1=pd.DataFrame(ans1)
ans2=pd.DataFrame(ans2)

# %%
y_testing=pd.concat([Y1_test,Y2_test])
y_predicted=pd.concat([ans1,ans2])
k2=mean_squared_error(y_predicted,y_testing)
print(k2)
# Out:
# 0.41830943396226417

# %% [markdown]
# #  So total mean squared error is equal to 0.398 after combining the data for regression

# %% [markdown]
# I have the the random forest regressor after trying so many algorithms such as ridge,lasso, linear ,svr regressions
# to make the predictions.Now this algorithm  since it is a non linear algo is taking the most imp features into consideration and thus making prediction with least error
